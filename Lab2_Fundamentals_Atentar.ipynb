# %%
ENGINEER = "Atentar"
STUDENT_ID = "TUPM-25-0014"

SEED_NUM = int(STUDENT_ID[-1])

print(f"System Initialized for: {ENGINEER}")
print(F"Algorithmic Seed Value: {SEED_NUM}")
# Out:
# System Initialized for: Atentar
# Algorithmic Seed Value: 4

# %%
actual = 0.1 + 0.2

print(f"Python stores: {actual}")

if actual == 0.3:
    print("Result: Perfect Match")
else:
    print("Result: PRECISION ERROR (Binary Artifact)")
# Out:
# Python stores: 0.30000000000000004
# Result: PRECISION ERROR (Binary Artifact)

# %%
first_letter = ENGINEER[0]
byte_value = ord(first_letter)

print(f"Character: {first_letter}")
print(f"ASCII Byte Value: {byte_value}")
print(f"Next in Sequence: {chr(byte_value + 1)}")
# Out:
# Character: A
# ASCII Byte Value: 65
# Next in Sequence: B

# %%
raw_in = input("Enter Name (add messy spaces): ")
cleaned_in = raw_in.strip().upper()
print(f"Original: '{raw_in}'| Cleaned: '{cleaned_in}'")
# Out:
# Original: 'NERI'| Cleaned: 'NERI'

# %%
user_input = input("Press Enter (leave empty) or type data: ")

if user_input:
    print(f"Data detected: {user_input}")
else:
    print("No data stream detected.")
# Out:
# Data detected: HALLLO

# %%
campus = STUDENT_ID[0:4]
unique_id = STUDENT_ID[8:]

tokens = STUDENT_ID.split("-")

print(f"Campus Code: {campus}")
print(f"Unique Identifier: {unique_id}")
print(f"Token List: {tokens}")
# Out:
# Campus Code: TUPM
# Unique Identifier: 0014
# Token List: ['TUPM', '25', '0014']

# %%
if SEED_NUM % 2 == 0:
    priority = "LOW (Even Seed)"
else:
    priority = "HIGH (Odd Seed)"
print(f"System Priority: {priority}")
# Out:
# System Priority: LOW (Even Seed)

# %%
limit = (SEED_NUM * 10) + 20
print(F"--- SAFETY LIMIT: {limit} ---")

val = int(input("Enter Sensor Reading: "))

if val > limit:
    print("ALERT: Over Limit")
elif val < 5:
    print("ALERT: Low Signal")
else:
    print("STATUS: Nominal")
# Out:
# --- SAFETY LIMIT: 60 ---
# ALERT: Low Signal

# %%
try:
    voltage = int(input("Enter Voltage (Numeric): "))
    print(f"Voltage Captured: {voltage}V")
except ValueError:
    print("SYSTEM ERROR: Input must be numeric. Resetting to 0.")
    voltage = 0
print(f"System continues... Current Voltage: {voltage}V")
# Out:
# SYSTEM ERROR: Input must be numeric. Resetting to 0.
# System continues... Current Voltage: 0V

# %%
has_power = False

if has_power and (10 / 0 == 0):
    print("System On")
else:
    print("System Off (Short-Circuit Detected)")
# Out:
# System Off (Short-Circuit Detected)

# %%
loops = SEED_NUM + 3
print(f"--- RUNNING {loops} CYCLES ---")

for i in range(1, loops + 1):
    print(f"Cycle {i}/{loops}: ...Complete")
# Out:
# --- RUNNING 7 CYCLES ---
# Cycle 1/7: ...Complete
# Cycle 2/7: ...Complete
# Cycle 3/7: ...Complete
# Cycle 4/7: ...Complete
# Cycle 5/7: ...Complete
# Cycle 6/7: ...Complete
# Cycle 7/7: ...Complete

# %%
rows = int(tokens[2][0])
cols = int(tokens[2][-1])
print(f"Generating {rows}x{cols} Matrix:")

for r in range(rows):
    for c in range(cols):
        print("#", end="")
    print()
# Out:
# Generating 0x4 Matrix:

# %%
while True:
    pwd = input("Type 'ADMIN' to exit: ")
    if pwd == "ADMIN":
        print("Unlocked.")
        break
    else:
        print("Access Denied")
# Out:
# Access Denied
# Unlocked.

# %%
A = byte_value
B = SEED_NUM
C = loops

verification_hash = (A * B) - C

print(f"User: {ENGINEER}")
print(f"Forensic Signature: {verification_hash}")
# Out:
# User: Atentar
# Forensic Signature: 253
