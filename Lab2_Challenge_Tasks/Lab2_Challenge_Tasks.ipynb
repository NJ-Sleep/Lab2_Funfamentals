# %%
import Lab2_Fundamentals_Atentar

# %%
target_name = "ATENTAR"
SEED_NUM = 4
redacted_name = ""

for i in target_name:
    if i == "A" or i == "E" or i == "I" or i == "O" or i == "U":
        target_name = target_name.replace(i, str(SEED_NUM))
print(target_name)
# Out:
# 4T4NT4R

# %%
ENGINEER = "ATENTAR"
ASCII = ord(ENGINEER[0])
loops = SEED_NUM + 3
verification_hash = (ASCII * SEED_NUM) - loops

# %%
correct_password = "Madrigal"
attempts = 0

while True:
    pwd = input("Enter Password: (PASSWORD)")
    if pwd == correct_password:
        print("Access granted")
        break
    else:
        print("Access Denied")
        attempts += 1
print(f"Total attempts: {attempts}")
# Out:
# Access Denied
# Access Denied
# Access Denied
# Access granted
# Total attempts: 3
